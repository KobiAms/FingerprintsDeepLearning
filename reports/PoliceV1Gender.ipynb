# %%
from os import listdir
from os.path import isfile, join
from io import StringIO
import pandas as pd
from IPython.display import Image, display

STUDIES = [FINGER_NAME, FINGERPRINT_TYPE, GENDER, SAME_PERSON] = ['FingerName', 'FingerprintType', 'GenderStudy', 'SamePerson']
SOCOFING_DATASETS = [SOCOFingGender, SOCOFingFingers, SOCOFingSamePerson] = ['SOCOFingGender', 'SOCOFingFingers', 'SOCOFingSamePerson']
NISTDB4_DATASETS = [NISTSDB4Gender, NISTSDB4Type, NISTSDB4Fingers] = ['NISTSDB4Gender', 'NISTSDB4Type', 'NISTSDB4Fingers']
POLICE_V1_DATASETS = [PoliceV1Gender, PoliceV1SamePerson, PoliceV1Fingers] = ['PoliceV1Gender', 'PoliceV1SamePerson', 'PoliceV1Fingers']
POLICE_V2_DATASETS = [PoliceV2Gender, PoliceV2SamePerson, PoliceV2Fingers] = ['PoliceV2Gender', 'PoliceV2SamePerson', 'PoliceV2Fingers']
NIST300_A_DATASETS = [NISTSDB300aFingers, NISTSDB300aSamePerson] = ['NISTSDB300aFingers', 'NISTSDB300aSamePerson']
NIST300_B_DATASETS = [NISTSDB302bFingers, NISTSDB302bSamePerson] = ['NISTSDB302bFingers', 'NISTSDB302bSamePerson']

OUTPUTS_IMG = [DSSI_IMG, TLM_IMG, LR_IMG, DSSMP_IMG, LOSS_IMG, OPT_IMG, CLSS_IMG, BB_IMG] = ['DatasetSplitInformation.png', 
                                                    'Comparison Transfer Learning Mode.png', 'Comparison Learning Rate.png', 
                                                    'DatasetSamples.png', 'Comparison Loss Functions.png', 
                                                    'Comparison Optimizer.png', 'Comparison Classifiers.png', 'Comparison DNN Backbone.png']
OUTPUTS_CSV = [DSSI_CSV, ABLHIS_CSV, BST_HIST_CSV]= ['DatasetSplitInformation.csv', 'ablationHistory.csv', 'full_history.csv']
COPRIZONS_IMGS = [TLM_IMG, BB_IMG, CLSS_IMG, LOSS_IMG, LR_IMG, OPT_IMG]


STUDY = GENDER
DATASET = PoliceV1Gender

path = './{}/{}/'.format(STUDY, DATASET)
final_modal_path=f'{path}FinalModels/'
cmpr = iter(COPRIZONS_IMGS)
abl_csv = pd.read_csv(f'{path}{ABLHIS_CSV}')

# %%
print('\n\n\t\t\t', DATASET, 'Dataset split information')
display(Image(f'{path}{DSSMP_IMG}'))
display(Image(f'{path}{DSSI_IMG}'))
pd.read_csv(f'{path}{DSSI_CSV}')
# Out:
# 			 PoliceV1Gender Dataset split information
#    Unnamed: 0    M    W   SUM
# 0       Train  439  472   911
# 1        Test   90   90   180
# 2  Validation   90   90   180
# 3         SUM  619  652  1271

# %%
comp_name = next(cmpr)
print('\n\n\t\t\t', comp_name[:-4])
df = abl_csv.iloc[:4]
display(Image(f'{path}{comp_name}'))
display(pd.read_csv(StringIO(df.to_csv(header=False)), sep=",", header=None))
# Out:
# 			 Comparison Transfer Learning Mode
#                0      1       2       3       4       5       6       7   \
# 0           Study    E-0     E-1     E-2     E-3     E-4     E-5     E-6
# 1  PT&Untrainable  80.0%  86.11%  96.11%  92.78%  93.33%  94.44%  92.78%
# 2    PT&Trainable  50.0%  50.56%  50.56%  76.67%  50.56%  60.56%  58.33%
# 3    IN&Trainable  50.0%   50.0%   50.0%   50.0%   50.0%   50.0%   50.0%
#
#        8       9       10
# 0     E-7     E-8     E-9
# 1   90.0%  93.33%  92.22%
# 2  55.56%  53.33%  56.11%
# 3   50.0%   50.0%   50.0%

# %%
comp_name = next(cmpr)
print('\n\n\t\t\t', comp_name[:-4])
df = abl_csv.iloc[4:11]
display(Image(f'{path}{comp_name}'))
display(pd.read_csv(StringIO(df.to_csv(header=False)), sep=",", header=None))
# Out:
# 			 Comparison DNN Backbone
#                         0                1                    2   \
# 0             BestBackbone  optimizer: Adam  learningRate: 0.001
# 1                    Study              E-0                  E-1
# 2        ResNet50-Backbone           87.78%               89.44%
# 3  EfficientNetB2-Backbone           68.89%               73.89%
# 4     InceptionV3-Backbone            50.0%               50.56%
# 5        Xception-Backbone           54.44%               51.11%
# 6       Backbone_MobileNet            80.0%               86.11%
#
#                           3                  4       5       6       7   \
# 0  loss: binary_crossentropy  metrics: accuracy     NaN     NaN     NaN
# 1                        E-2                E-3     E-4     E-5     E-6
# 2                     91.67%             92.78%  93.89%  93.33%  93.89%
# 3                     76.67%             76.11%   80.0%  81.11%  75.56%
# 4                     78.33%             76.11%  57.78%  83.89%  72.78%
# 5                     61.11%              50.0%   50.0%   50.0%   50.0%
# 6                     96.11%             92.78%  93.33%  94.44%  92.78%
#
#        8       9       10
# 0     NaN     NaN     NaN
# 1     E-7     E-8     E-9
# 2  91.67%  92.78%  94.44%
# 3   80.0%   80.0%  82.22%
# 4  86.11%  91.11%  77.22%
# 5   50.0%   50.0%   50.0%
# 6   90.0%  93.33%  92.22%

# %%
comp_name = next(cmpr)
print('\n\n\t\t\t', comp_name[:-4])
df = abl_csv.iloc[11:17]
display(Image(f'{path}{comp_name}'))
display(pd.read_csv(StringIO(df.to_csv(header=False)), sep=",", header=None))
# Out:
# 			 Comparison Classifiers
#                              0                1                    2   \
# 0                bestClassifier  optimizer: Adam  learningRate: 0.001
# 1                         Study              E-0                  E-1
# 2            AlexNet-Classifier           92.22%                90.0%
# 3          MobileNet-Classifier           87.22%               91.11%
# 4             ResNet-Classifier           87.22%               89.44%
# 5  Classifier_DefaultClassifier           87.78%               89.44%
#
#                           3                  4       5       6       7   \
# 0  loss: binary_crossentropy  metrics: accuracy     NaN     NaN     NaN
# 1                        E-2                E-3     E-4     E-5     E-6
# 2                     91.11%             89.44%  91.67%  82.78%  92.78%
# 3                      90.0%             86.67%  88.33%  89.44%  92.22%
# 4                     91.67%             91.67%  91.67%  92.78%  91.11%
# 5                     91.67%             92.78%  93.89%  93.33%  93.89%
#
#        8       9       10
# 0     NaN     NaN     NaN
# 1     E-7     E-8     E-9
# 2  93.89%  91.11%  92.22%
# 3   90.0%  91.11%  87.78%
# 4  91.67%  92.22%  92.78%
# 5  91.67%  92.78%  94.44%

# %%
comp_name = next(cmpr)
print('\n\n\t\t\t', comp_name[:-4])
df = abl_csv.iloc[17:22]
display(Image(f'{path}{comp_name}'))
display(pd.read_csv(StringIO(df.to_csv(header=False)), sep=",", header=None))
# Out:
# 			 Comparison Loss Functions
#                                  0                1                    2   \
# 0                          BestLoss  optimizer: Adam  learningRate: 0.001
# 1                             Study              E-0                  E-1
# 2   LossFunction_mean_squared_error            50.0%                50.0%
# 3                LossFunction_hinge            50.0%                50.0%
# 4  LossFunction_binary_crossentropy           87.78%               89.44%
#
#                   3       4       5       6       7       8       9       10
# 0  metrics: accuracy     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1                E-2     E-3     E-4     E-5     E-6     E-7     E-8     E-9
# 2              50.0%   50.0%   70.0%  51.67%  86.67%  81.11%   50.0%   50.0%
# 3             72.22%   50.0%  73.89%  58.89%  64.44%  84.44%  79.44%  77.22%
# 4             91.67%  92.78%  93.89%  93.33%  93.89%  91.67%  92.78%  94.44%

# %%
comp_name = next(cmpr)
print('\n\n\t\t\t', comp_name[:-4])
df = abl_csv.iloc[22:29]
display(Image(f'{path}{comp_name}'))
display(pd.read_csv(StringIO(df.to_csv(header=False)), sep=",", header=None))
# Out:
# 			 Comparison Learning Rate
#                     0                1                          2   \
# 0     BestLearningRate  optimizer: Adam  loss: binary_crossentropy
# 1                Study              E-0                        E-1
# 2     LearningRate_0.1            50.0%                      50.0%
# 3    LearningRate_0.01            50.0%                      50.0%
# 4  LearningRate_0.0001           82.78%                     85.56%
# 5   LearningRate_1e-05           45.56%                      70.0%
# 6   LearningRate_0.001           87.78%                     89.44%
#
#                   3       4       5       6       7       8       9       10
# 0  metrics: accuracy     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1                E-2     E-3     E-4     E-5     E-6     E-7     E-8     E-9
# 2              50.0%   50.0%   50.0%   50.0%   50.0%   50.0%   50.0%   50.0%
# 3              50.0%   50.0%   50.0%   50.0%   50.0%   50.0%   50.0%   50.0%
# 4             88.89%   90.0%  87.78%  92.22%  92.78%  93.33%  94.44%  94.44%
# 5             77.78%  81.67%  84.44%  83.89%  84.44%  84.44%   85.0%  85.56%
# 6             91.67%  92.78%  93.89%  93.33%  93.89%  91.67%  92.78%  94.44%

# %%
comp_name = next(cmpr)
print('\n\n\t\t\t', comp_name[:-4])
df = abl_csv.iloc[29:]
display(Image(f'{path}{comp_name}'))
display(pd.read_csv(StringIO(df.to_csv(header=False)), sep=",", header=None))
# Out:
# 			 Comparison Optimizer
#                   0                     1                          2   \
# 0     BestOptimizier  learningRate: 0.0001  loss: binary_crossentropy
# 1              Study                   E-0                        E-1
# 2    Optimizer_Nadam                82.78%                     82.78%
# 3  Optimizer_RMSprop                83.33%                     83.89%
# 4     Optimizer_Adam                82.78%                     85.56%
#
#                   3       4       5       6       7       8       9       10
# 0  metrics: accuracy     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1                E-2     E-3     E-4     E-5     E-6     E-7     E-8     E-9
# 2              90.0%  89.44%  89.44%   90.0%  91.67%  88.33%  90.56%  92.78%
# 3             86.11%  87.78%   90.0%  92.22%  89.44%  92.22%   90.0%  89.44%
# 4             88.89%   90.0%  87.78%  92.22%  92.78%  93.33%  94.44%  94.44%

# %%
full_hist = pd.read_csv(f'{final_modal_path}FinalModels/{BST_HIST_CSV}', on_bad_lines='skip', names=[x for x in range(0, 71)])

model_name = full_hist.iloc[0, 0]
print(model_name)
display(Image(f'{final_modal_path}FinalModels/{model_name}.png'))

model_name = full_hist.iloc[6, 0]
print(model_name)
display(Image(f'{final_modal_path}FinalModels/{model_name}.png'))
# Out:
# LearningRate_0.0001
# LearningRate_0.001
