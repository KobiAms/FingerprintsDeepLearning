# %%
from os import listdir
from os.path import isfile, join
from io import StringIO
import pandas as pd
from IPython.display import Image, display

STUDIES = [FINGER_NAME, FINGERPRINT_TYPE, GENDER, SAME_PERSON] = ['FingerName', 'FingerprintType', 'GenderStudy', 'SamePerson']
SOCOFING_DATASETS = [SOCOFingGender, SOCOFingFingers, SOCOFingSamePerson] = ['SOCOFingGender', 'SOCOFingFingers', 'SOCOFingSamePerson']
NISTDB4_DATASETS = [NISTSDB4Gender, NISTSDB4Type, NISTSDB4Fingers] = ['NISTSDB4Gender', 'NISTSDB4Type', 'NISTSDB4Fingers']
NIST300_A_DATASETS = [NISTSDB300aFingers, NISTSDB300aSamePerson] = ['NISTSDB300aFingers', 'NISTSDB300aSamePerson']
NIST300_B_DATASETS = [NISTSDB302bFingers, NISTSDB302bSamePerson] = ['NISTSDB302bFingers', 'NISTSDB302bSamePerson']

OUTPUTS_IMG = [DSSI_IMG, TLM_IMG, LR_IMG, DSSMP_IMG, LOSS_IMG, OPT_IMG, CLSS_IMG, BB_IMG] = ['DatasetSplitInformation.png', 
                                                    'Comparison Transfer Learning Mode.png', 'Comparison Learning Rate.png', 
                                                    'DatasetSamples.png', 'Comparison Loss Functions.png', 
                                                    'Comparison Optimizer.png', 'Comparison Classifiers.png', 'Comparison DNN Backbone.png']
OUTPUTS_CSV = [DSSI_CSV, ABLHIS_CSV, BST_HIST_CSV]= ['DatasetSplitInformation.csv', 'ablationHistory.csv', 'full_history.csv']
COPRIZONS_IMGS = [TLM_IMG, BB_IMG, CLSS_IMG, LOSS_IMG, LR_IMG, OPT_IMG]


STUDY = GENDER
DATASET = NISTSDB4Gender

path = './{}/{}/'.format(STUDY, DATASET)
final_modal_path=f'{path}FinalModels/'
cmpr = iter(COPRIZONS_IMGS)
abl_csv = pd.read_csv(f'{path}{ABLHIS_CSV}')

# %%
print('\n\n\t\t\t', DATASET, 'Dataset split information')
display(Image(f'{path}{DSSMP_IMG}'))
display(Image(f'{path}{DSSI_IMG}'))
pd.read_csv(f'{path}{DSSI_CSV}')
# Out:
# 			 NISTSDB4Gender Dataset split information
#    Unnamed: 0    F     M   SUM
# 0       Train  534  2266  2800
# 1        Test  104   496   600
# 2  Validation  112   488   600
# 3         SUM  750  3250  4000

# %%
comp_name = next(cmpr)
print('\n\n\t\t\t', comp_name[:-4])
df = abl_csv.iloc[:4]
display(Image(f'{path}{comp_name}'))
display(pd.read_csv(StringIO(df.to_csv(header=False)), sep=",", header=None))
# Out:
# 			 Comparison Transfer Learning Mode
#                0       1       2       3       4       5       6       7   \
# 0           Study     E-0     E-1     E-2     E-3     E-4     E-5     E-6
# 1  PT&Untrainable  81.33%  81.33%   81.5%  84.83%   84.5%  85.17%  86.17%
# 2    PT&Trainable  81.33%  81.33%  81.33%  81.33%  81.33%   82.0%  81.33%
# 3    IN&Trainable  81.33%  81.33%  81.33%  81.33%  81.33%  18.67%  81.33%
#
#        8       9       10
# 0     E-7     E-8     E-9
# 1   85.5%  83.67%   83.0%
# 2  81.33%  81.33%  81.67%
# 3  81.33%  81.33%  81.33%

# %%
comp_name = next(cmpr)
print('\n\n\t\t\t', comp_name[:-4])
df = abl_csv.iloc[4:11]
display(Image(f'{path}{comp_name}'))
display(pd.read_csv(StringIO(df.to_csv(header=False)), sep=",", header=None))
# Out:
# 			 Comparison DNN Backbone
#                         0                1                    2   \
# 0             BestBackbone  optimizer: Adam  learningRate: 0.001
# 1                    Study              E-0                  E-1
# 2        ResNet50-Backbone           82.83%                86.0%
# 3  EfficientNetB2-Backbone           81.83%               82.33%
# 4     InceptionV3-Backbone           81.33%               81.33%
# 5        Xception-Backbone           81.33%               81.83%
# 6       Backbone_MobileNet           81.33%               81.33%
#
#                           3                  4       5       6       7   \
# 0  loss: binary_crossentropy  metrics: accuracy     NaN     NaN     NaN
# 1                        E-2                E-3     E-4     E-5     E-6
# 2                      84.5%              84.5%  85.17%  86.67%  84.83%
# 3                     81.33%             84.17%  84.67%   85.5%  85.17%
# 4                     81.33%             81.33%  81.33%  81.33%  81.33%
# 5                     82.33%             81.33%  81.33%   81.5%   81.5%
# 6                      81.5%             84.83%   84.5%  85.17%  86.17%
#
#        8       9       10
# 0     NaN     NaN     NaN
# 1     E-7     E-8     E-9
# 2  86.67%  86.17%   86.5%
# 3   86.5%   86.5%  85.83%
# 4  81.33%  81.33%  81.33%
# 5   83.0%  83.67%  83.33%
# 6   85.5%  83.67%   83.0%

# %%
comp_name = next(cmpr)
print('\n\n\t\t\t', comp_name[:-4])
df = abl_csv.iloc[11:17]
display(Image(f'{path}{comp_name}'))
display(pd.read_csv(StringIO(df.to_csv(header=False)), sep=",", header=None))
# Out:
# 			 Comparison Classifiers
#                              0                1                    2   \
# 0                bestClassifier  optimizer: Adam  learningRate: 0.001
# 1                         Study              E-0                  E-1
# 2            AlexNet-Classifier            87.0%                82.0%
# 3          MobileNet-Classifier           83.67%               84.33%
# 4             ResNet-Classifier           84.83%                86.0%
# 5  Classifier_DefaultClassifier           82.83%                86.0%
#
#                           3                  4       5       6       7   \
# 0  loss: binary_crossentropy  metrics: accuracy     NaN     NaN     NaN
# 1                        E-2                E-3     E-4     E-5     E-6
# 2                      87.5%             85.83%   87.0%   84.5%   85.0%
# 3                      86.5%              88.0%  86.33%   85.0%   87.5%
# 4                     86.17%              86.0%  87.33%   88.0%  86.33%
# 5                      84.5%              84.5%  85.17%  86.67%  84.83%
#
#        8       9       10
# 0     NaN     NaN     NaN
# 1     E-7     E-8     E-9
# 2  86.67%  86.67%  86.33%
# 3   87.5%  87.83%  87.17%
# 4  85.67%  86.83%  87.83%
# 5  86.67%  86.17%   86.5%

# %%
comp_name = next(cmpr)
print('\n\n\t\t\t', comp_name[:-4])
df = abl_csv.iloc[17:22]
display(Image(f'{path}{comp_name}'))
display(pd.read_csv(StringIO(df.to_csv(header=False)), sep=",", header=None))
# Out:
# 			 Comparison Loss Functions
#                                  0                1                    2   \
# 0                          BestLoss  optimizer: Adam  learningRate: 0.001
# 1                             Study              E-0                  E-1
# 2   LossFunction_mean_squared_error           81.33%               81.33%
# 3                LossFunction_hinge           81.33%               81.33%
# 4  LossFunction_binary_crossentropy           84.83%                86.0%
#
#                   3       4       5       6       7       8       9       10
# 0  metrics: accuracy     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1                E-2     E-3     E-4     E-5     E-6     E-7     E-8     E-9
# 2             81.33%  81.33%  81.33%  81.33%  81.33%  81.33%  81.33%  81.33%
# 3             81.33%  81.33%  81.33%  81.33%  81.33%  81.33%  81.33%  81.33%
# 4             86.17%   86.0%  87.33%   88.0%  86.33%  85.67%  86.83%  87.83%

# %%
comp_name = next(cmpr)
print('\n\n\t\t\t', comp_name[:-4])
df = abl_csv.iloc[22:29]
display(Image(f'{path}{comp_name}'))
display(pd.read_csv(StringIO(df.to_csv(header=False)), sep=",", header=None))
# Out:
# 			 Comparison Learning Rate
#                     0                1                          2   \
# 0     BestLearningRate  optimizer: Adam  loss: binary_crossentropy
# 1                Study              E-0                        E-1
# 2     LearningRate_0.1           82.83%                     83.83%
# 3    LearningRate_0.01           81.33%                     83.83%
# 4  LearningRate_0.0001           81.67%                      83.0%
# 5   LearningRate_1e-05           77.67%                     78.83%
# 6   LearningRate_0.001           84.83%                      86.0%
#
#                   3       4       5       6       7       8       9       10
# 0  metrics: accuracy     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1                E-2     E-3     E-4     E-5     E-6     E-7     E-8     E-9
# 2             82.17%  84.17%   82.5%  84.33%  81.83%   85.0%  85.33%   85.0%
# 3              86.5%   85.5%  82.67%  84.33%  76.67%  82.17%  85.17%  85.67%
# 4             83.83%  84.33%  84.17%  84.33%  84.67%  85.33%   86.5%  86.33%
# 5              79.5%   79.5%   80.5%  80.33%  79.83%  80.83%  81.17%  81.67%
# 6             86.17%   86.0%  87.33%   88.0%  86.33%  85.67%  86.83%  87.83%

# %%
comp_name = next(cmpr)
print('\n\n\t\t\t', comp_name[:-4])
df = abl_csv.iloc[29:]
display(Image(f'{path}{comp_name}'))
display(pd.read_csv(StringIO(df.to_csv(header=False)), sep=",", header=None))
# Out:
# 			 Comparison Optimizer
#                   0                    1                          2   \
# 0     BestOptimizier  learningRate: 0.001  loss: binary_crossentropy
# 1              Study                  E-0                        E-1
# 2    Optimizer_Nadam               84.83%                      82.0%
# 3  Optimizer_RMSprop                81.5%                      86.5%
# 4     Optimizer_Adam               84.83%                      86.0%
#
#                   3       4       5       6       7       8       9       10
# 0  metrics: accuracy     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1                E-2     E-3     E-4     E-5     E-6     E-7     E-8     E-9
# 2             70.67%  77.17%   83.0%   82.5%  83.67%  69.17%  83.67%   88.0%
# 3             86.33%  83.83%  82.83%  83.17%  87.67%   88.0%  87.67%   88.0%
# 4             86.17%   86.0%  87.33%   88.0%  86.33%  85.67%  86.83%  87.83%

# %%
full_hist = pd.read_csv(f'{final_modal_path}FinalModels/{BST_HIST_CSV}', on_bad_lines='skip', names=[x for x in range(0, 71)])
full_hist.iloc[0, 0]

model_name = full_hist.iloc[0, 0]
print(model_name)
display(Image(f'{final_modal_path}FinalModels/{model_name}.png'))
display(full_hist.iloc[1:5])

model_name = full_hist.iloc[6, 0]
print(model_name)
display(Image(f'{final_modal_path}FinalModels/{model_name}.png'))
display(full_hist.iloc[7:11])

model_name = full_hist.iloc[12, 0]
print(model_name)
display(Image(f'{final_modal_path}FinalModels/{model_name}.png'))
display(full_hist.iloc[13:17])
# Out:
# Optimizer_Nadam
#                 0         1         2         3         4         5   \
# 1         Accuracy  0.792143  0.844286  0.864286  0.858214  0.891071
# 2     Val Accuracy  0.848333  0.820000  0.706667  0.771667  0.830000
# 3             Loss  0.779388  0.514978  0.431109  0.396991  0.324500
# 4  Validation Loss  0.587740  0.766819  0.869218  1.031466  0.639967
#
#          6         7         8         9   ...  61  62  63  64  65  66  67  \
# 1  0.877857  0.899286  0.905357  0.910357  ... NaN NaN NaN NaN NaN NaN NaN
# 2  0.825000  0.836667  0.691667  0.836667  ... NaN NaN NaN NaN NaN NaN NaN
# 3  0.345395  0.290391  0.245017  0.239219  ... NaN NaN NaN NaN NaN NaN NaN
# 4  0.512469  0.483886  0.947767  0.647434  ... NaN NaN NaN NaN NaN NaN NaN
#
#    68  69  70
# 1 NaN NaN NaN
# 2 NaN NaN NaN
# 3 NaN NaN NaN
# 4 NaN NaN NaN
#
# [4 rows x 71 columns]
# Optimizer_RMSprop
#                  0         1         2         3         4         5   \
# 7          Accuracy  0.781071  0.814286  0.828929  0.846429  0.857143
# 8      Val Accuracy  0.815000  0.865000  0.863333  0.838333  0.828333
# 9              Loss  0.994856  0.728061  0.631941  0.570683  0.525358
# 10  Validation Loss  0.961196  0.520008  0.438213  0.563481  0.861511
#
#           6         7         8         9   ...  61  62  63  64  65  66  67  \
# 7   0.860000  0.864643  0.879286  0.881786  ... NaN NaN NaN NaN NaN NaN NaN
# 8   0.831667  0.876667  0.880000  0.876667  ... NaN NaN NaN NaN NaN NaN NaN
# 9   0.490669  0.456206  0.432279  0.438367  ... NaN NaN NaN NaN NaN NaN NaN
# 10  0.732752  0.424175  0.435110  0.432652  ... NaN NaN NaN NaN NaN NaN NaN
#
#     68  69  70
# 7  NaN NaN NaN
# 8  NaN NaN NaN
# 9  NaN NaN NaN
# 10 NaN NaN NaN
#
# [4 rows x 71 columns]
# ResNet-Classifier
#                  0         1         2         3         4         5   \
# 13         Accuracy  0.802857  0.849286  0.868571  0.887143  0.897500
# 14     Val Accuracy  0.848333  0.860000  0.861667  0.860000  0.873333
# 15             Loss  0.739094  0.458811  0.378435  0.316672  0.286468
# 16  Validation Loss  0.480079  0.414887  0.443280  0.411949  0.385795
#
#           6         7         8         9   ...        61        62        63  \
# 13  0.887143  0.912143  0.927857  0.932143  ...  0.999118  0.998823  0.998823
# 14  0.880000  0.863333  0.856667  0.868333  ...  0.890000  0.866667  0.843333
# 15  0.300472  0.235364  0.202201  0.184856  ...  0.019943  0.021311  0.020132
# 16  0.392181  0.405953  0.407615  0.372925  ...  0.518835  0.533141  0.608821
#
#           64        65        66        67        68        69        70
# 13  0.999706  1.000000  1.000000  0.999412  0.999412  0.999412  0.999706
# 14  0.871667  0.856667  0.861667  0.858333  0.895000  0.851667  0.841667
# 15  0.019766  0.017013  0.017070  0.018838  0.016758  0.018636  0.014335
# 16  0.535454  0.545550  0.544977  0.562449  0.575474  0.577894  0.637032
#
# [4 rows x 71 columns]
