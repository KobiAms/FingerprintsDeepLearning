# %%
from os import listdir
from os.path import isfile, join
from io import StringIO
import pandas as pd
from IPython.display import Image, display

STUDIES = [FINGER_NAME, FINGERPRINT_TYPE, GENDER, SAME_PERSON] = ['FingerName', 'FingerprintType', 'GenderStudy', 'SamePerson']
SOCOFING_DATASETS = [SOCOFingGender, SOCOFingFingers, SOCOFingSamePerson] = ['SOCOFingGender', 'SOCOFingFingers', 'SOCOFingSamePerson']
NISTDB4_DATASETS = [NISTSDB4Gender, NISTSDB4Type, NISTSDB4Fingers] = ['NISTSDB4Gender', 'NISTSDB4Type', 'NISTSDB4Fingers']
NIST300_A_DATASETS = [NISTSDB300aFingers, NISTSDB300aSamePerson] = ['NISTSDB300aFingers', 'NISTSDB300aSamePerson']
NIST300_B_DATASETS = [NISTSDB302bFingers, NISTSDB302bSamePerson] = ['NISTSDB302bFingers', 'NISTSDB302bSamePerson']

OUTPUTS_IMG = [DSSI_IMG, TLM_IMG, LR_IMG, DSSMP_IMG, LOSS_IMG, OPT_IMG, CLSS_IMG, BB_IMG] = ['DatasetSplitInformation.png', 
                                                    'Comparison Transfer Learning Mode.png', 'Comparison Learning Rate.png', 
                                                    'DatasetSamples.png', 'Comparison Loss Functions.png', 
                                                    'Comparison Optimizer.png', 'Comparison Classifiers.png', 'Comparison DNN Backbone.png']
OUTPUTS_CSV = [DSSI_CSV, ABLHIS_CSV, BST_HIST_CSV]= ['DatasetSplitInformation.csv', 'ablationHistory.csv', 'full_history.csv']
COPRIZONS_IMGS = [TLM_IMG, BB_IMG, CLSS_IMG, LOSS_IMG, LR_IMG, OPT_IMG]


STUDY = FINGER_NAME
DATASET = SOCOFingFingers

path = './{}/{}/'.format(STUDY, DATASET)
final_modal_path=f'{path}FinalModels/'
cmpr = iter(COPRIZONS_IMGS)
abl_csv = pd.read_csv(f'{path}{ABLHIS_CSV}')

# %%
print('\n\n\t\t\t', DATASET, 'Dataset split information')
display(Image(f'{path}{DSSMP_IMG}'))
display(Image(f'{path}{DSSI_IMG}'))
pd.read_csv(f'{path}{DSSI_CSV}')
# Out:
# 			 SOCOFingFingers Dataset split information
#    Unnamed: 0  Right_thumb  Right_index  Right_middle  Right_ring  \
# 0       Train          420          420           420         420
# 1        Test           90           90            90          90
# 2  Validation           90           90            90          90
# 3         SUM          600          600           600         600
#
#    Right_little  Left_thumb  Left_index  Left_middle  Left_ring  Left_little  \
# 0           420         420         420          420        420          420
# 1            90          90          90           90         90           90
# 2            90          90          90           90         90           90
# 3           600         600         600          600        600          600
#
#     SUM
# 0  4200
# 1   900
# 2   900
# 3  6000

# %%
comp_name = next(cmpr)
print('\n\n\t\t\t', comp_name[:-4])
df = abl_csv.iloc[:4]
display(Image(f'{path}{comp_name}'))
display(pd.read_csv(StringIO(df.to_csv(header=False)), sep=",", header=None))
# Out:
# 			 Comparison Transfer Learning Mode
#                0       1       2       3       4       5       6       7   \
# 0           Study     E-0     E-1     E-2     E-3     E-4     E-5     E-6
# 1  PT&Untrainable  24.67%  32.44%  30.33%  37.33%  39.33%  38.56%  38.67%
# 2    PT&Trainable   10.0%   9.11%  10.44%  15.11%  12.33%   10.0%  12.33%
# 3    IN&Trainable   10.0%   10.0%   10.0%   10.0%   10.0%   10.0%   10.0%
#
#        8       9       10
# 0     E-7     E-8     E-9
# 1  41.56%  38.33%  38.11%
# 2  20.22%  28.67%  21.11%
# 3   10.0%   10.0%   10.0%

# %%
comp_name = next(cmpr)
print('\n\n\t\t\t', comp_name[:-4])
df = abl_csv.iloc[4:11]
display(Image(f'{path}{comp_name}'))
display(pd.read_csv(StringIO(df.to_csv(header=False)), sep=",", header=None))
# Out:
# 			 Comparison DNN Backbone
#                         0                1                    2   \
# 0             BestBackbone  optimizer: Adam  learningRate: 0.001
# 1                    Study              E-0                  E-1
# 2        ResNet50-Backbone           10.33%               15.22%
# 3  EfficientNetB2-Backbone            10.0%               14.44%
# 4     InceptionV3-Backbone            10.0%                10.0%
# 5        Xception-Backbone           10.11%                10.0%
# 6       Backbone_MobileNet           24.67%               32.44%
#
#                                3                  4       5       6       7   \
# 0  loss: categorical_crossentropy  metrics: accuracy     NaN     NaN     NaN
# 1                             E-2                E-3     E-4     E-5     E-6
# 2                          17.89%             22.22%  25.11%  30.44%  36.56%
# 3                          18.11%             19.67%  20.56%  21.33%  23.89%
# 4                           10.0%              10.0%   10.0%  14.78%    8.0%
# 5                           10.0%              10.0%   10.0%  10.78%  10.11%
# 6                          30.33%             37.33%  39.33%  38.56%  38.67%
#
#        8       9       10
# 0     NaN     NaN     NaN
# 1     E-7     E-8     E-9
# 2  40.89%  40.22%  36.78%
# 3  18.56%  19.44%   19.0%
# 4  14.78%   9.33%   10.0%
# 5   10.0%   10.0%   10.0%
# 6  41.56%  38.33%  38.11%

# %%
comp_name = next(cmpr)
print('\n\n\t\t\t', comp_name[:-4])
df = abl_csv.iloc[11:17]
display(Image(f'{path}{comp_name}'))
display(pd.read_csv(StringIO(df.to_csv(header=False)), sep=",", header=None))
# Out:
# 			 Comparison Classifiers
#                              0                1                    2   \
# 0                bestClassifier  optimizer: Adam  learningRate: 0.001
# 1                         Study              E-0                  E-1
# 2            AlexNet-Classifier           30.89%               32.89%
# 3          MobileNet-Classifier           34.33%               40.89%
# 4             ResNet-Classifier            34.0%               39.78%
# 5  Classifier_DefaultClassifier           24.67%               32.44%
#
#                                3                  4       5       6       7   \
# 0  loss: categorical_crossentropy  metrics: accuracy     NaN     NaN     NaN
# 1                             E-2                E-3     E-4     E-5     E-6
# 2                          31.56%             33.33%  34.67%  21.44%  26.89%
# 3                           42.0%             44.11%  49.33%  46.67%  50.78%
# 4                          42.33%              41.0%  47.44%   47.0%  46.89%
# 5                          30.33%             37.33%  39.33%  38.56%  38.67%
#
#        8       9       10
# 0     NaN     NaN     NaN
# 1     E-7     E-8     E-9
# 2  25.22%  31.56%  30.67%
# 3  48.67%  49.67%   47.0%
# 4  49.89%  49.78%  48.22%
# 5  41.56%  38.33%  38.11%

# %%
comp_name = next(cmpr)
print('\n\n\t\t\t', comp_name[:-4])
df = abl_csv.iloc[17:22]
display(Image(f'{path}{comp_name}'))
display(pd.read_csv(StringIO(df.to_csv(header=False)), sep=",", header=None))
# Out:
# 			 Comparison Loss Functions
#                                       0                1   \
# 0                               BestLoss  optimizer: Adam
# 1                                  Study              E-0
# 2        LossFunction_mean_squared_error            24.0%
# 3         LossFunction_categorical_hinge            20.0%
# 4  LossFunction_categorical_crossentropy            34.0%
#
#                     2                  3       4       5       6       7   \
# 0  learningRate: 0.001  metrics: accuracy     NaN     NaN     NaN     NaN
# 1                  E-1                E-2     E-3     E-4     E-5     E-6
# 2               28.44%             28.33%  29.44%  25.78%   31.0%  30.44%
# 3               22.56%             20.22%  24.44%  24.56%  29.11%  24.56%
# 4               39.78%             42.33%   41.0%  47.44%   47.0%  46.89%
#
#        8       9       10
# 0     NaN     NaN     NaN
# 1     E-7     E-8     E-9
# 2  23.11%  32.11%  29.78%
# 3  24.89%  29.56%  27.67%
# 4  49.89%  49.78%  48.22%

# %%
comp_name = next(cmpr)
print('\n\n\t\t\t', comp_name[:-4])
df = abl_csv.iloc[22:29]
display(Image(f'{path}{comp_name}'))
display(pd.read_csv(StringIO(df.to_csv(header=False)), sep=",", header=None))
# Out:
# 			 Comparison Learning Rate
#                     0                1                               2   \
# 0     BestLearningRate  optimizer: Adam  loss: categorical_crossentropy
# 1                Study              E-0                             E-1
# 2     LearningRate_0.1           29.67%                          30.89%
# 3    LearningRate_0.01           34.67%                           42.0%
# 4  LearningRate_0.0001           18.11%                           24.0%
# 5   LearningRate_1e-05            12.0%                          12.56%
# 6   LearningRate_0.001            34.0%                          39.78%
#
#                   3       4       5       6       7       8       9       10
# 0  metrics: accuracy     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1                E-2     E-3     E-4     E-5     E-6     E-7     E-8     E-9
# 2             40.89%  38.78%  49.44%  45.56%  45.89%  48.22%  43.33%  46.11%
# 3             43.89%  44.22%  42.44%  49.22%  48.22%   43.0%  46.78%  45.89%
# 4             30.11%  34.33%  35.33%  37.56%  39.33%  39.67%  41.67%  42.67%
# 5             12.78%  13.89%  14.67%  14.89%  15.78%  17.22%  17.56%  17.78%
# 6             42.33%   41.0%  47.44%   47.0%  46.89%  49.89%  49.78%  48.22%

# %%
comp_name = next(cmpr)
print('\n\n\t\t\t', comp_name[:-4])
df = abl_csv.iloc[29:]
display(Image(f'{path}{comp_name}'))
display(pd.read_csv(StringIO(df.to_csv(header=False)), sep=",", header=None))
# Out:
# 			 Comparison Optimizer
#                   0                    1                               2   \
# 0     BestOptimizier  learningRate: 0.001  loss: categorical_crossentropy
# 1              Study                  E-0                             E-1
# 2    Optimizer_Nadam               28.33%                          39.33%
# 3  Optimizer_RMSprop               29.89%                          27.33%
# 4     Optimizer_Adam                34.0%                          39.78%
#
#                   3       4       5       6       7       8       9       10
# 0  metrics: accuracy     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1                E-2     E-3     E-4     E-5     E-6     E-7     E-8     E-9
# 2             38.89%  37.11%   42.0%  42.33%  45.44%  41.44%  48.44%  50.11%
# 3             35.78%  31.22%  35.11%   28.0%  40.67%  42.67%  33.67%  37.11%
# 4             42.33%   41.0%  47.44%   47.0%  46.89%  49.89%  49.78%  48.22%

# %%
full_hist = pd.read_csv(f'{final_modal_path}FinalModels/{BST_HIST_CSV}', on_bad_lines='skip', names=[x for x in range(0, 71)])
full_hist.iloc[0, 0]

model_name = full_hist.iloc[0, 0]
print(model_name)
display(Image(f'{final_modal_path}FinalModels/{model_name}.png'))
display(full_hist.iloc[1:5])

model_name = full_hist.iloc[6, 0]
print(model_name)
display(Image(f'{final_modal_path}FinalModels/{model_name}.png'))
display(full_hist.iloc[7:11])

model_name = full_hist.iloc[12, 0]
print(model_name)
display(Image(f'{final_modal_path}FinalModels/{model_name}.png'))
display(full_hist.iloc[13:17])
# Out:
# Optimizer_Nadam
#                 0         1         2         3         4         5   \
# 1         Accuracy  0.262619  0.413571  0.465714  0.523333  0.550476
# 2     Val Accuracy  0.283333  0.393333  0.388889  0.371111  0.420000
# 3             Loss  2.634979  1.835264  1.592723  1.432773  1.306143
# 4  Validation Loss  3.220839  2.130146  2.100432  2.437921  1.992513
#
#          6         7         8         9   ...  61  62  63  64  65  66  67  \
# 1  0.581190  0.614762  0.628571  0.634524  ... NaN NaN NaN NaN NaN NaN NaN
# 2  0.423333  0.454444  0.414444  0.484444  ... NaN NaN NaN NaN NaN NaN NaN
# 3  1.219084  1.117503  1.049196  1.013583  ... NaN NaN NaN NaN NaN NaN NaN
# 4  2.034178  1.847876  1.992936  1.660861  ... NaN NaN NaN NaN NaN NaN NaN
#
#    68  69  70
# 1 NaN NaN NaN
# 2 NaN NaN NaN
# 3 NaN NaN NaN
# 4 NaN NaN NaN
#
# [4 rows x 71 columns]
# ResNet-Classifier
#                  0         1         2         3         4         5   \
# 7          Accuracy  0.269048  0.427619  0.490238  0.528095  0.565952
# 8      Val Accuracy  0.340000  0.397778  0.423333  0.410000  0.474444
# 9              Loss  2.649921  1.719210  1.508620  1.395051  1.255920
# 10  Validation Loss  2.149778  1.970438  1.825799  1.980611  1.730862
#
#           6         7         8         9   ...  61  62  63  64  65  66  67  \
# 7   0.591905  0.621190  0.640714  0.654286  ... NaN NaN NaN NaN NaN NaN NaN
# 8   0.470000  0.468889  0.498889  0.497778  ... NaN NaN NaN NaN NaN NaN NaN
# 9   1.179258  1.093958  1.014791  0.966571  ... NaN NaN NaN NaN NaN NaN NaN
# 10  1.818603  1.679479  1.634425  1.606486  ... NaN NaN NaN NaN NaN NaN NaN
#
#     68  69  70
# 7  NaN NaN NaN
# 8  NaN NaN NaN
# 9  NaN NaN NaN
# 10 NaN NaN NaN
#
# [4 rows x 71 columns]
# MobileNet-Classifier
#                  0         1         2         3         4         5   \
# 13         Accuracy  0.240476  0.364524  0.414286  0.437381  0.468810
# 14     Val Accuracy  0.343333  0.408889  0.420000  0.441111  0.493333
# 15             Loss  3.640561  2.642544  2.341982  2.030540  1.931797
# 16  Validation Loss  2.329383  2.008317  1.894886  1.835643  1.641533
#
#           6         7         8         9   ...  61  62  63  64  65  66  67  \
# 13  0.495952  0.514524  0.531190  0.550238  ... NaN NaN NaN NaN NaN NaN NaN
# 14  0.466667  0.507778  0.486667  0.496667  ... NaN NaN NaN NaN NaN NaN NaN
# 15  1.702351  1.631537  1.506571  1.417960  ... NaN NaN NaN NaN NaN NaN NaN
# 16  1.833991  1.558891  1.746283  1.621051  ... NaN NaN NaN NaN NaN NaN NaN
#
#     68  69  70
# 13 NaN NaN NaN
# 14 NaN NaN NaN
# 15 NaN NaN NaN
# 16 NaN NaN NaN
#
# [4 rows x 71 columns]
