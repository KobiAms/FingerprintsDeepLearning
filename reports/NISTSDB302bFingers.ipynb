# %%
from os import listdir
from os.path import isfile, join
from io import StringIO
import pandas as pd
from IPython.display import Image, display

STUDIES = [FINGER_NAME, FINGERPRINT_TYPE, GENDER, SAME_PERSON] = ['FingerName', 'FingerprintType', 'GenderStudy', 'SamePerson']
SOCOFING_DATASETS = [SOCOFingGender, SOCOFingFingers, SOCOFingSamePerson] = ['SOCOFingGender', 'SOCOFingFingers', 'SOCOFingSamePerson']
NISTDB4_DATASETS = [NISTSDB4Gender, NISTSDB4Type, NISTSDB4Fingers] = ['NISTSDB4Gender', 'NISTSDB4Type', 'NISTSDB4Fingers']
POLICE_V1_DATASETS = [PoliceV1Gender, PoliceV1SamePerson, PoliceV1Fingers] = ['PoliceV1Gender', 'PoliceV1SamePerson', 'PoliceV1Fingers']
POLICE_V2_DATASETS = [PoliceV2Gender, PoliceV2SamePerson, PoliceV2Fingers] = ['PoliceV2Gender', 'PoliceV2SamePerson', 'PoliceV2Fingers']
NIST300_A_DATASETS = [NISTSDB300aFingers, NISTSDB300aSamePerson] = ['NISTSDB300aFingers', 'NISTSDB300aSamePerson']
NIST300_B_DATASETS = [NISTSDB302bFingers, NISTSDB302bSamePerson] = ['NISTSDB302bFingers', 'NISTSDB302bSamePerson']

OUTPUTS_IMG = [DSSI_IMG, TLM_IMG, LR_IMG, DSSMP_IMG, LOSS_IMG, OPT_IMG, CLSS_IMG, BB_IMG] = ['DatasetSplitInformation.png', 
                                                    'Comparison Transfer Learning Mode.png', 'Comparison Learning Rate.png', 
                                                    'DatasetSamples.png', 'Comparison Loss Functions.png', 
                                                    'Comparison Optimizer.png', 'Comparison Classifiers.png', 'Comparison DNN Backbone.png']
OUTPUTS_CSV = [DSSI_CSV, ABLHIS_CSV, BST_HIST_CSV]= ['DatasetSplitInformation.csv', 'ablationHistory.csv', 'full_history.csv']
COPRIZONS_IMGS = [TLM_IMG, BB_IMG, CLSS_IMG, LOSS_IMG, LR_IMG, OPT_IMG]


STUDY = FINGER_NAME
DATASET = NISTSDB302bFingers

path = './{}/{}/'.format(STUDY, DATASET)
final_modal_path=f'{path}FinalModels/'
cmpr = iter(COPRIZONS_IMGS)
abl_csv = pd.read_csv(f'{path}{ABLHIS_CSV}')

# %%
print('\n\n\t\t\t', DATASET, 'Dataset split information')
display(Image(f'{path}{DSSMP_IMG}'))
display(Image(f'{path}{DSSI_IMG}'))
pd.read_csv(f'{path}{DSSI_CSV}')
# Out:
# 			 NISTSDB302bFingers Dataset split information
#    Unnamed: 0  01  02  03  04  05  06  07  08  09  10  SUM
# 0       Train  20  20  20  20  20  20  20  20  20  19  199
# 1        Test   4   4   4   4   4   4   4   4   4   4   40
# 2  Validation   4   4   4   4   4   3   4   4   4   5   40
# 3         SUM  28  28  28  28  28  27  28  28  28  28  279

# %%
comp_name = next(cmpr)
print('\n\n\t\t\t', comp_name[:-4])
df = abl_csv.iloc[:4]
display(Image(f'{path}{comp_name}'))
display(pd.read_csv(StringIO(df.to_csv(header=False)), sep=",", header=None))
# Out:
# 			 Comparison Transfer Learning Mode
#                 0      1      2      3      4      5
# 0           Study    E-0    E-1    E-2    E-3    E-4
# 1  PT&Untrainable   5.0%  10.0%  17.5%  12.5%  10.0%
# 2    PT&Trainable   7.5%  10.0%  12.5%  10.0%   7.5%
# 3    IN&Trainable  10.0%  10.0%  10.0%  10.0%  10.0%

# %%
comp_name = next(cmpr)
print('\n\n\t\t\t', comp_name[:-4])
df = abl_csv.iloc[4:11]
display(Image(f'{path}{comp_name}'))
display(pd.read_csv(StringIO(df.to_csv(header=False)), sep=",", header=None))
# Out:
# 			 Comparison DNN Backbone
#                          0                1                    2  \
# 0             BestBackbone  optimizer: Adam  learningRate: 0.001
# 1                    Study              E-0                  E-1
# 2        ResNet50-Backbone             5.0%                12.5%
# 3  EfficientNetB2-Backbone            15.0%                 7.5%
# 4     InceptionV3-Backbone            12.5%                20.0%
# 5        Xception-Backbone            27.5%                10.0%
# 6       Backbone_MobileNet             5.0%                10.0%
#
#                                 3                  4      5
# 0  loss: categorical_crossentropy  metrics: accuracy    NaN
# 1                             E-2                E-3    E-4
# 2                           10.0%               7.5%   7.5%
# 3                           12.5%              12.5%  10.0%
# 4                           10.0%              10.0%  10.0%
# 5                           20.0%               7.5%   7.5%
# 6                           17.5%              12.5%  10.0%

# %%
comp_name = next(cmpr)
print('\n\n\t\t\t', comp_name[:-4])
df = abl_csv.iloc[11:17]
display(Image(f'{path}{comp_name}'))
display(pd.read_csv(StringIO(df.to_csv(header=False)), sep=",", header=None))
# Out:
# 			 Comparison Classifiers
#                               0                1                    2  \
# 0                bestClassifier  optimizer: Adam  learningRate: 0.001
# 1                         Study              E-0                  E-1
# 2            AlexNet-Classifier            10.0%                15.0%
# 3          MobileNet-Classifier             7.5%                10.0%
# 4             ResNet-Classifier             7.5%                12.5%
# 5  Classifier_DefaultClassifier            15.0%                 7.5%
#
#                                 3                  4      5
# 0  loss: categorical_crossentropy  metrics: accuracy    NaN
# 1                             E-2                E-3    E-4
# 2                           15.0%              12.5%  22.5%
# 3                            7.5%              10.0%  12.5%
# 4                           15.0%              10.0%   7.5%
# 5                           12.5%              12.5%  10.0%

# %%
comp_name = next(cmpr)
print('\n\n\t\t\t', comp_name[:-4])
df = abl_csv.iloc[17:22]
display(Image(f'{path}{comp_name}'))
display(pd.read_csv(StringIO(df.to_csv(header=False)), sep=",", header=None))
# Out:
# 			 Comparison Loss Functions
#                                        0                1  \
# 0                               BestLoss  optimizer: Adam
# 1                                  Study              E-0
# 2        LossFunction_mean_squared_error            12.5%
# 3         LossFunction_categorical_hinge            10.0%
# 4  LossFunction_categorical_crossentropy            10.0%
#
#                      2                  3      4      5
# 0  learningRate: 0.001  metrics: accuracy    NaN    NaN
# 1                  E-1                E-2    E-3    E-4
# 2                12.5%              12.5%  12.5%  12.5%
# 3                10.0%              10.0%  10.0%  10.0%
# 4                15.0%              15.0%  12.5%  22.5%

# %%
comp_name = next(cmpr)
print('\n\n\t\t\t', comp_name[:-4])
df = abl_csv.iloc[22:29]
display(Image(f'{path}{comp_name}'))
display(pd.read_csv(StringIO(df.to_csv(header=False)), sep=",", header=None))
# Out:
# 			 Comparison Learning Rate
#                      0                1                               2  \
# 0     BestLearningRate  optimizer: Adam  loss: categorical_crossentropy
# 1                Study              E-0                             E-1
# 2     LearningRate_0.1             7.5%                           10.0%
# 3    LearningRate_0.01             7.5%                            7.5%
# 4  LearningRate_0.0001            10.0%                           10.0%
# 5   LearningRate_1e-05            12.5%                           17.5%
# 6   LearningRate_0.001            10.0%                           15.0%
#
#                    3      4      5
# 0  metrics: accuracy    NaN    NaN
# 1                E-2    E-3    E-4
# 2              10.0%  12.5%  10.0%
# 3              10.0%  12.5%  10.0%
# 4              20.0%  25.0%  25.0%
# 5              12.5%  12.5%  10.0%
# 6              15.0%  12.5%  22.5%

# %%
comp_name = next(cmpr)
print('\n\n\t\t\t', comp_name[:-4])
df = abl_csv.iloc[29:]
display(Image(f'{path}{comp_name}'))
display(pd.read_csv(StringIO(df.to_csv(header=False)), sep=",", header=None))
# Out:
# 			 Comparison Optimizer
#                    0                     1                               2  \
# 0     BestOptimizier  learningRate: 0.0001  loss: categorical_crossentropy
# 1              Study                   E-0                             E-1
# 2    Optimizer_Nadam                 12.5%                           10.0%
# 3  Optimizer_RMSprop                 10.0%                           10.0%
# 4     Optimizer_Adam                 10.0%                           10.0%
#
#                    3      4      5
# 0  metrics: accuracy    NaN    NaN
# 1                E-2    E-3    E-4
# 2               7.5%  12.5%  15.0%
# 3              27.5%  17.5%  17.5%
# 4              20.0%  25.0%  25.0%

# %%
full_hist = pd.read_csv(f'{final_modal_path}FinalModels/{BST_HIST_CSV}', on_bad_lines='skip', names=[x for x in range(0, 17)])
full_hist.iloc[0, 0]

model_name = full_hist.iloc[0, 0]
print(model_name)
display(Image(f'{final_modal_path}FinalModels/{model_name}.png'))
display(full_hist.iloc[1:5])

model_name = full_hist.iloc[6, 0]
print(model_name)
display(Image(f'{final_modal_path}FinalModels/{model_name}.png'))
display(full_hist.iloc[7:11])

model_name = full_hist.iloc[12, 0]
print(model_name)
display(Image(f'{final_modal_path}FinalModels/{model_name}.png'))
display(full_hist.iloc[13:17])

model_name = full_hist.iloc[18, 0]
print(model_name)
display(Image(f'{final_modal_path}FinalModels/{model_name}.png'))
display(full_hist.iloc[19:23])

model_name = full_hist.iloc[24, 0]
print(model_name)
display(Image(f'{final_modal_path}FinalModels/{model_name}.png'))
display(full_hist.iloc[25:29])
# Out:
# LearningRate_0.0001
#                 0          1         2         3         4         5   \
# 1         Accuracy   0.085427  0.110553  0.125628  0.175879  0.201005
# 2     Val Accuracy   0.100000  0.100000  0.200000  0.250000  0.250000
# 3             Loss  10.089406  9.538545  6.963041  5.682407  4.891196
# 4  Validation Loss   3.150304  4.217639  3.063722  2.682575  2.486290
#
#          6         7         8         9         10        11        12  \
# 1  0.205021  0.179916  0.209205  0.301255  0.267782  0.221757  0.288703
# 2  0.225000  0.200000  0.175000  0.200000  0.275000  0.250000  0.200000
# 3  4.131368  3.866836  3.304574  2.782835  2.707937  2.744832  2.470970
# 4  3.037841  2.444427  2.614759  2.321201  2.501866  2.409024  2.276035
#
#          13        14        15  16
# 1  0.288703  0.317992  0.338912 NaN
# 2  0.275000  0.250000  0.275000 NaN
# 3  2.220282  2.210745  2.147433 NaN
# 4  2.402943  2.295577  2.307063 NaN
# AlexNet-Classifier
#                  0          1         2         3         4         5   \
# 7          Accuracy   0.090452  0.120603  0.095477  0.090452  0.135678
# 8      Val Accuracy   0.100000  0.150000  0.150000  0.125000  0.225000
# 9              Loss  41.289070  6.235286  3.609369  2.666628  2.387365
# 10  Validation Loss   5.634350  2.954400  2.318476  2.264964  2.204436
#
#           6         7         8         9         10        11        12  \
# 7   0.129707  0.142259  0.125523  0.121339  0.167364  0.121339  0.142259
# 8   0.125000  0.175000  0.125000  0.125000  0.100000  0.150000  0.200000
# 9   2.302106  2.282483  2.283895  2.297047  2.256524  2.325692  2.311457
# 10  2.282197  2.235485  2.274282  2.190487  2.204230  2.259874  2.234666
#
#           13        14        15  16
# 7   0.167364  0.175732  0.146444 NaN
# 8   0.150000  0.175000  0.125000 NaN
# 9   2.278017  2.249005  2.246749 NaN
# 10  2.157719  2.228020  2.230612 NaN
# Optimizer_RMSprop
#                  0          1         2         3         4         5   \
# 13         Accuracy   0.095477  0.135678  0.130653  0.125628  0.190955
# 14     Val Accuracy   0.100000  0.100000  0.275000  0.175000  0.175000
# 15             Loss  17.413351  8.604369  5.998286  5.101335  4.018088
# 16  Validation Loss   5.855923  6.186122  3.852263  4.553934  4.295150
#
#           6         7         8         9         10        11        12  \
# 13  0.179916  0.205021  0.242678  0.230126  0.200837  0.280335  0.267782
# 14  0.150000  0.100000  0.225000  0.125000  0.250000  0.200000  0.200000
# 15  4.333151  3.423440  2.920383  2.884254  2.919727  2.613121  2.621603
# 16  3.063811  2.587327  2.544974  2.894392  2.521147  2.491260  2.820660
#
#           13        14        15  16
# 13  0.251046  0.309623  0.280335 NaN
# 14  0.275000  0.150000  0.225000 NaN
# 15  2.430960  2.378530  2.377037 NaN
# 16  2.358038  2.429388  2.491829 NaN
# Optimizer_Nadam
#                  0         1          2         3         4         5   \
# 19         Accuracy  0.095477   0.100503  0.145729  0.185930  0.180905
# 20     Val Accuracy  0.125000   0.100000  0.075000  0.125000  0.150000
# 21             Loss  9.406805   8.182959  7.321231  5.264707  5.206087
# 22  Validation Loss  6.165900  11.004037  6.935381  6.834560  4.771087
#
#           6         7         8         9         10        11        12  \
# 19  0.213389  0.179916  0.209205  0.221757  0.280335  0.280335  0.263598
# 20  0.200000  0.175000  0.125000  0.200000  0.300000  0.150000  0.225000
# 21  4.484220  4.003407  3.687899  3.466530  3.064493  2.751383  2.512247
# 22  3.748194  3.376505  2.659609  3.075942  2.708533  2.732227  2.818731
#
#           13        14        15  16
# 19  0.276151  0.313808  0.326360 NaN
# 20  0.250000  0.200000  0.125000 NaN
# 21  2.491076  2.462409  2.183526 NaN
# 22  2.490912  2.304665  2.660588 NaN
# MobileNet-Classifier
#                  0         1         2         3         4         5   \
# 25         Accuracy  0.095477  0.100503  0.125628  0.100503  0.115578
# 26     Val Accuracy  0.075000  0.100000  0.075000  0.100000  0.125000
# 27             Loss  9.189906  7.594493  5.961499  5.922010  5.033517
# 28  Validation Loss  6.882207  4.574849  4.272221  4.066532  3.251926
#
#           6         7         8         9         10        11        12  \
# 25  0.150628  0.184100  0.225941  0.238494  0.200837  0.230126  0.213389
# 26  0.075000  0.100000  0.100000  0.100000  0.100000  0.025000  0.150000
# 27  4.696548  4.067882  4.054934  3.714095  3.669222  3.555193  3.191880
# 28  4.371916  4.125289  5.139813  3.259803  4.980046  4.007625  3.570542
#
#           13        14        15  16
# 25  0.313808  0.280335  0.309623 NaN
# 26  0.100000  0.075000  0.100000 NaN
# 27  2.904485  2.881068  2.635116 NaN
# 28  4.132513  3.823035  3.925571 NaN
