# %%
from os import listdir
from os.path import isfile, join
from io import StringIO
import pandas as pd
from IPython.display import Image, display

STUDIES = [FINGER_NAME, FINGERPRINT_TYPE, GENDER, SAME_PERSON] = ['FingerName', 'FingerprintType', 'GenderStudy', 'SamePerson']
SOCOFING_DATASETS = [SOCOFingGender, SOCOFingFingers, SOCOFingSamePerson] = ['SOCOFingGender', 'SOCOFingFingers', 'SOCOFingSamePerson']
NISTDB4_DATASETS = [NISTSDB4Gender, NISTSDB4Type, NISTSDB4Fingers] = ['NISTSDB4Gender', 'NISTSDB4Type', 'NISTSDB4Fingers']
POLICE_V1_DATASETS = [PoliceV1Gender, PoliceV1SamePerson, PoliceV1Fingers] = ['PoliceV1Gender', 'PoliceV1SamePerson', 'PoliceV1Fingers']
POLICE_V2_DATASETS = [PoliceV2Gender, PoliceV2SamePerson, PoliceV2Fingers] = ['PoliceV2Gender', 'PoliceV2SamePerson', 'PoliceV2Fingers']
NIST300_A_DATASETS = [NISTSDB300aFingers, NISTSDB300aSamePerson] = ['NISTSDB300aFingers', 'NISTSDB300aSamePerson']
NIST300_B_DATASETS = [NISTSDB302bFingers, NISTSDB302bSamePerson] = ['NISTSDB302bFingers', 'NISTSDB302bSamePerson']

OUTPUTS_IMG = [DSSI_IMG, TLM_IMG, LR_IMG, DSSMP_IMG, LOSS_IMG, OPT_IMG, CLSS_IMG, BB_IMG] = ['DatasetSplitInformation.png', 
                                                    'Comparison Transfer Learning Mode.png', 'Comparison Learning Rate.png', 
                                                    'DatasetSamples.png', 'Comparison Loss Functions.png', 
                                                    'Comparison Optimizer.png', 'Comparison Classifiers.png', 'Comparison DNN Backbone.png']
OUTPUTS_CSV = [DSSI_CSV, ABLHIS_CSV, BST_HIST_CSV]= ['DatasetSplitInformation.csv', 'ablationHistory.csv', 'full_history.csv']
COPRIZONS_IMGS = [TLM_IMG, BB_IMG, CLSS_IMG, LOSS_IMG, LR_IMG, OPT_IMG]


STUDY = FINGER_NAME
DATASET = PoliceV1Fingers

path = './{}/{}/'.format(STUDY, DATASET)
final_modal_path=f'{path}FinalModels/'
cmpr = iter(COPRIZONS_IMGS)
abl_csv = pd.read_csv(f'{path}{ABLHIS_CSV}')

# %%
print('\n\n\t\t\t', DATASET, 'Dataset split information')
display(Image(f'{path}{DSSMP_IMG}'))
display(Image(f'{path}{DSSI_IMG}'))
pd.read_csv(f'{path}{DSSI_CSV}')
# Out:
# 			 PoliceV1Fingers Dataset split information
#    Unnamed: 0  01   02   03   04   05  06   07   08   09   10   SUM
# 0       Train   7  115  106  108  113   5  113  100  108  116   891
# 1        Test   2   23   24   24   24   2   23   23   23   22   190
# 2  Validation   0   24   20   24   25   0   24   22   25   26   190
# 3         SUM   9  162  150  156  162   7  160  145  156  164  1271

# %%
comp_name = next(cmpr)
print('\n\n\t\t\t', comp_name[:-4])
df = abl_csv.iloc[:4]
display(Image(f'{path}{comp_name}'))
display(pd.read_csv(StringIO(df.to_csv(header=False)), sep=",", header=None))
# Out:
# 			 Comparison Transfer Learning Mode
#                0       1       2       3       4       5       6       7   \
# 0           Study     E-0     E-1     E-2     E-3     E-4     E-5     E-6
# 1  PT&Untrainable  10.53%  13.16%  13.16%  12.63%  16.32%  17.37%  17.89%
# 2    PT&Trainable  12.11%  13.16%  13.68%  13.68%  12.63%  10.53%  16.32%
# 3    IN&Trainable  12.63%  12.63%  12.63%  12.63%  12.63%  12.63%  12.63%
#
#        8       9       10
# 0     E-7     E-8     E-9
# 1  18.95%  22.11%  22.11%
# 2   8.42%  12.63%  12.63%
# 3  12.63%  12.63%  12.63%

# %%
comp_name = next(cmpr)
print('\n\n\t\t\t', comp_name[:-4])
df = abl_csv.iloc[4:11]
display(Image(f'{path}{comp_name}'))
display(pd.read_csv(StringIO(df.to_csv(header=False)), sep=",", header=None))
# Out:
# 			 Comparison DNN Backbone
#                         0                1                    2   \
# 0             BestBackbone  optimizer: Adam  learningRate: 0.001
# 1                    Study              E-0                  E-1
# 2        ResNet50-Backbone           12.63%               13.16%
# 3  EfficientNetB2-Backbone           14.21%               11.58%
# 4     InceptionV3-Backbone           11.58%               11.58%
# 5        Xception-Backbone           11.05%               13.16%
# 6       Backbone_MobileNet           10.53%               13.16%
#
#                                3                  4       5       6       7   \
# 0  loss: categorical_crossentropy  metrics: accuracy     NaN     NaN     NaN
# 1                             E-2                E-3     E-4     E-5     E-6
# 2                          13.68%             15.26%  10.53%   10.0%   10.0%
# 3                          13.16%             12.63%  12.63%  14.74%  12.63%
# 4                          11.58%             12.63%  12.63%  17.37%   20.0%
# 5                          13.16%             13.16%  13.16%  13.16%  13.16%
# 6                          13.16%             12.63%  16.32%  17.37%  17.89%
#
#        8       9       10
# 0     NaN     NaN     NaN
# 1     E-7     E-8     E-9
# 2  11.58%  12.63%  16.84%
# 3  15.79%  13.16%  15.26%
# 4  13.68%  13.68%  12.63%
# 5  13.16%  13.16%  13.16%
# 6  18.95%  22.11%  22.11%

# %%
comp_name = next(cmpr)
print('\n\n\t\t\t', comp_name[:-4])
df = abl_csv.iloc[11:17]
display(Image(f'{path}{comp_name}'))
display(pd.read_csv(StringIO(df.to_csv(header=False)), sep=",", header=None))
# Out:
# 			 Comparison Classifiers
#                              0                1                    2   \
# 0                bestClassifier  optimizer: Adam  learningRate: 0.001
# 1                         Study              E-0                  E-1
# 2            AlexNet-Classifier           14.21%               24.21%
# 3          MobileNet-Classifier           26.32%                30.0%
# 4             ResNet-Classifier           22.63%               26.84%
# 5  Classifier_DefaultClassifier           10.53%               13.16%
#
#                                3                  4       5       6       7   \
# 0  loss: categorical_crossentropy  metrics: accuracy     NaN     NaN     NaN
# 1                             E-2                E-3     E-4     E-5     E-6
# 2                          13.68%             31.58%  27.89%  29.47%  35.79%
# 3                          28.95%             37.89%  36.32%  36.84%   40.0%
# 4                          26.84%              30.0%  34.21%  36.32%  39.47%
# 5                          13.16%             12.63%  16.32%  17.37%  17.89%
#
#        8       9       10
# 0     NaN     NaN     NaN
# 1     E-7     E-8     E-9
# 2   30.0%  28.95%  23.68%
# 3  42.11%  41.58%  35.79%
# 4  36.32%  41.58%  42.63%
# 5  18.95%  22.11%  22.11%

# %%
comp_name = next(cmpr)
print('\n\n\t\t\t', comp_name[:-4])
df = abl_csv.iloc[17:22]
display(Image(f'{path}{comp_name}'))
display(pd.read_csv(StringIO(df.to_csv(header=False)), sep=",", header=None))
# Out:
# 			 Comparison Loss Functions
#                                       0                1   \
# 0                               BestLoss  optimizer: Adam
# 1                                  Study              E-0
# 2        LossFunction_mean_squared_error           16.32%
# 3         LossFunction_categorical_hinge            6.32%
# 4  LossFunction_categorical_crossentropy           22.63%
#
#                     2                  3       4       5       6       7   \
# 0  learningRate: 0.001  metrics: accuracy     NaN     NaN     NaN     NaN
# 1                  E-1                E-2     E-3     E-4     E-5     E-6
# 2               15.79%             21.05%  23.16%  22.63%  21.58%  26.32%
# 3               12.11%             13.16%  21.05%  22.63%  20.53%  22.11%
# 4               26.84%             26.84%   30.0%  34.21%  36.32%  39.47%
#
#        8       9       10
# 0     NaN     NaN     NaN
# 1     E-7     E-8     E-9
# 2  24.21%  23.16%  22.11%
# 3  22.11%  22.63%  19.47%
# 4  36.32%  41.58%  42.63%

# %%
comp_name = next(cmpr)
print('\n\n\t\t\t', comp_name[:-4])
df = abl_csv.iloc[22:29]
display(Image(f'{path}{comp_name}'))
display(pd.read_csv(StringIO(df.to_csv(header=False)), sep=",", header=None))
# Out:
# 			 Comparison Learning Rate
#                     0                1                               2   \
# 0     BestLearningRate  optimizer: Adam  loss: categorical_crossentropy
# 1                Study              E-0                             E-1
# 2     LearningRate_0.1           16.84%                          35.26%
# 3    LearningRate_0.01           21.58%                           30.0%
# 4  LearningRate_0.0001           12.11%                          13.68%
# 5   LearningRate_1e-05           13.16%                          13.16%
# 6   LearningRate_0.001           22.63%                          26.84%
#
#                   3       4       5       6       7       8       9       10
# 0  metrics: accuracy     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1                E-2     E-3     E-4     E-5     E-6     E-7     E-8     E-9
# 2             28.42%  33.16%  38.42%  36.84%  36.84%  34.74%  44.21%  42.63%
# 3             34.74%  33.68%  39.47%  40.53%   30.0%  36.84%  37.37%  43.16%
# 4             12.63%  15.26%  14.74%  17.89%  18.42%  18.42%  21.05%  23.68%
# 5             13.16%  12.63%  13.16%  12.63%  12.63%  14.21%  14.21%  14.74%
# 6             26.84%   30.0%  34.21%  36.32%  39.47%  36.32%  41.58%  42.63%

# %%
comp_name = next(cmpr)
print('\n\n\t\t\t', comp_name[:-4])
df = abl_csv.iloc[29:]
display(Image(f'{path}{comp_name}'))
display(pd.read_csv(StringIO(df.to_csv(header=False)), sep=",", header=None))
# Out:
# 			 Comparison Optimizer
#                   0                   1                               2   \
# 0     BestOptimizier  learningRate: 0.01  loss: categorical_crossentropy
# 1              Study                 E-0                             E-1
# 2    Optimizer_Nadam              21.05%                          23.16%
# 3  Optimizer_RMSprop              13.16%                          13.68%
# 4     Optimizer_Adam              21.58%                           30.0%
#
#                   3       4       5       6       7       8       9       10
# 0  metrics: accuracy     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1                E-2     E-3     E-4     E-5     E-6     E-7     E-8     E-9
# 2              30.0%  37.37%  38.95%   30.0%  27.89%  46.84%  41.05%  35.79%
# 3              9.47%  13.68%  17.89%  22.11%  37.37%  31.05%  26.32%  37.89%
# 4             34.74%  33.68%  39.47%  40.53%   30.0%  36.84%  37.37%  43.16%

# %%
full_hist = pd.read_csv(f'{final_modal_path}FinalModels/{BST_HIST_CSV}')

model_name = full_hist.columns[0]
print(model_name)
display(Image(f'{final_modal_path}FinalModels/{model_name}.png'))
display(full_hist.iloc[0:4])

model_name = full_hist.iloc[5].name[0]
print(model_name)
display(Image(f'{final_modal_path}FinalModels/{model_name}.png'))
display(full_hist.iloc[6:10])

model_name = full_hist.iloc[11].name[0]
print(model_name)
display(Image(f'{final_modal_path}FinalModels/{model_name}.png'))
display(full_hist.iloc[12:16])

model_name = full_hist.iloc[17].name[0]
print(model_name)
display(Image(f'{final_modal_path}FinalModels/{model_name}.png'))
display(full_hist.iloc[18:22])

model_name = full_hist.iloc[23].name[0]
print(model_name)
display(Image(f'{final_modal_path}FinalModels/{model_name}.png'))
display(full_hist.iloc[24:28])
# Out:
# LearningRate_0.01
#                                                                                                                                                                                                                                                                                        LearningRate_0.01
# Accuracy        0.178451  0.309764 0.514029 0.528620 0.600449 0.649832 0.720539 0.685746 0.819304 0.832772 0.808511 0.756707 0.816836 0.813136 0.825162 0.857539 0.797410 0.760407 0.877891 0.797410 0.828862 0.821462 0.857539 0.802960 0.808511 0.884366 0.821462 0.851989 0.909343           0.949121
# Val Accuracy    0.215789  0.300000 0.347368 0.336842 0.394737 0.405263 0.300000 0.368421 0.373684 0.431579 0.326316 0.415789 0.384211 0.384211 0.352632 0.294737 0.315789 0.410526 0.331579 0.336842 0.342105 0.378947 0.357895 0.300000 0.326316 0.305263 0.331579 0.331579 0.357895           0.378947
