# %%
import tensorflow as tf
import datasets as ds
from FPMLmodule import utils
import numpy as np
from PIL import Image
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# %%
datasetsConfig = {
    'batchSize': 32, 
    'parallelTune': tf.data.AUTOTUNE, 
    'split': [0.7, 0.15, 0.15], 
    'inputDim': (224, 224, 3), 
    'seed': 9, 
    'shuffle': True
    }

NISTSDB300aGender = ds.NISTSDB4Gender(**datasetsConfig)
dataset = NISTSDB300aGender.create()
utils.datasetAnalysisAndDisplay(dataset, NISTSDB300aGender)

# %%
saved_model = tf.keras.models.load_model('./out/GenderStudy/NISTSDB4Gender/FinalModels/Optimizer_Nadam')

# %%
saved_model.evaluate(dataset[2])
# Out:
# 19/19 [==============================] - 7s 254ms/step - loss: 0.1027 - accuracy: 0.9483
# [0.10274380445480347, 0.9483333826065063]

# %%
f1751_08_M_T = Image.open(r"./images/nist4/f1751_08_M_T.png")
f1762_03_M_R = Image.open(r"./images/nist4/f1762_03_M_R.png")
f1769_07_M_T = Image.open(r"./images/nist4/f1769_07_M_T.png")
s1793_07_M_T = Image.open(r"./images/nist4/s1793_07_M_T.png")
s1819_03_M_R = Image.open(r"./images/nist4/s1819_03_M_R.png")

# %%
f1751_08_M_T_np =  np.array(f1751_08_M_T)
f1751_08_M_T_np

# predicted = saved_model.predict(f1751_08_M_T_np)
print(f1751_08_M_T_np.shape)
# Out:
# (512, 512)

# %%
saved_model.summary()
# Out:
# Model: "sequential_57"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  resnet50 (Functional)       (None, 2048)              23587712
#
#  ResNet-Classifier (Sequenti  (None, 2)                4098
#  al)
#
# ...
# Total params: 23,591,810
# Trainable params: 4,098
# Non-trainable params: 23,587,712
# _________________________________________________________________
